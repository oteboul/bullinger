# %%
import collections
import importlib
import glob
import os
import os.path
import matplotlib
from matplotlib.lines import Line2D
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format

os.chdir('/home/olivier/dev/bullinger/')
from bullinger import annotations, visualizer, aggregator
annotations = importlib.reload(annotations)
visualizer = importlib.reload(visualizer)
aggregator = importlib.reload(aggregator)

agg = aggregator.Aggregator('resources/')
agg_viz = visualizer.AggregationVisualizer(agg)

# %% [markdown]
# # Tableau complet

# %%
df = agg.metrics_df
df
# Out:
#     semester     ad  resp_all  stimu_all  instal_all  score_all  resp_avec  \
# 0          2  False      0.84       0.84       79.83       0.50        nan
# 1          1  False      1.00       1.00       61.74       0.50       1.00
# 2          1   True      0.03       0.79       89.60       0.00       0.05
# 3          2   True      0.02       0.79      125.76       0.00       0.03
# 4          2  False      0.00       0.12      129.90       0.00       0.00
# 5          1  False      0.32       0.45       75.23       0.34       0.32
# 6          2  False      0.57       0.73       76.85       0.38       0.50
# 7          1  False      1.00       0.97      199.82       0.52       1.00
# 8          1  False      1.00       0.73      211.94       0.65       1.00
# 9          2  False      0.94       0.79      155.25       0.58       0.90
# 10         1  False      0.18       0.15       69.32       0.56       0.18
# ...

# %% [markdown]
# # Bullinger: Resultat de taux de réponse avec et sans installation

# %%
agg_viz.distribution()

# %% [markdown]
# # Resultat principaux

# %%
df = agg.responses(median=False, as_index=True)
df
# Out:
#                 instal_all  instal_avec  instal_sans  resp_all  resp_avec  \
# ad    semester
# False 1              98.96         0.91         0.09      0.51       0.55
#       2             105.56         0.54         0.46      0.60       0.64
# True  1              85.70         0.93         0.07      0.36       0.37
#       2              94.93         0.40         0.60      0.30       0.45
#
#                 resp_sans  score_all  score_avec  score_sans  stimu_all  \
# ad    semester
# False 1              0.02      36.07       38.83        9.26       0.61
#       2              0.50      43.38       46.06       43.18       0.65
# True  1              0.02      34.71       35.40        0.00       0.52
#       2              0.19      28.40       35.54       27.80       0.57
#
#                 stimu_avec  stimu_sans
# ad    semester
# False 1               0.61        0.41
#       2               0.62        0.69
# True  1               0.54        0.80
# ...

# %%
agg_viz.stats_in_bar('score_avec,score_sans', s=2, percentage=False)
ax = plt.gca()
ax.set_title('Angle moyen (Semestre 2)', fontsize=20)
ax.set_xticklabels(['Avec\ninstallation', 'Sans\ninstallation'], fontsize=16)
# Out:
# [Text(0, 0, 'Avec\ninstallation'), Text(0, 0, 'Sans\ninstallation')]

# %%
axes = agg_viz.scatter(semesters=2, installations=['avec', 'sans'], plot_score=True)

# %%
agg_viz.stimuli(relative=True)

# %%
for baby in sorted(agg.per_baby.keys()):
    agg_viz.baby(baby, add_legend=False)
# Out:
# /home/olivier/dev/bullinger/bullinger/visualizer.py:150: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   for i, va in enumerate(vas):
