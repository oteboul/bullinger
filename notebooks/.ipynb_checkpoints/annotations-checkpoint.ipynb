# %%
import collections
import importlib
import glob
import os
import os.path

import matplotlib
from matplotlib.lines import Line2D
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format
print(os.getcwd())
# Out:
# /home/olivier/dev/bullinger

# %%
os.chdir('/home/olivier/dev/bullinger/')
from bullinger import annotations, visualizer, aggregator
annotations = importlib.reload(annotations)
visualizer = importlib.reload(visualizer)
aggregator = importlib.reload(aggregator)

agg = aggregator.Aggregator('resources/')
agg_viz = visualizer.AggregationVisualizer(agg)

# %% [markdown]
# # Bullinger: Resultat de taux de réponse avec et sans installation

# %%
agg_viz.distribution()

# %%
agg.responses
# Out:
#                 r_all  r_avec  r_sans  ratio  ratio_avec  ratio_sans  s_all  \
# ad    semester
# False 1         0.290   0.325   0.000  0.780       0.805       0.082  0.657
#       2         0.573   0.577   0.592  1.082       0.859       1.001  0.735
# True  1         0.383   0.391   0.025  0.745       0.826       0.025  0.520
#       2         0.359   0.568   0.196  0.862       0.769       0.863  0.510
#
#                 s_avec  s_sans
# ad    semester
# False 1          0.732   0.290
#       2          0.614   0.795
# True  1          0.516   0.805
#       2          0.667   0.478

# %%
df = agg.metrics_df
df[(df.semester == 2) & (df.ad == True)]
# Out:
#     semester    ad  r_all  s_all  r_avec  s_avec  r_sans  s_sans      baby
# 3          2  True  0.020  0.802   0.025   0.768   0.000   0.964   Lorenzo
# 14         2  True  0.843  0.467     nan     nan   0.893   0.478   Claudio
# 20         2  True  0.207  0.175   0.568   0.007   0.196   0.220   Arianna
# 22         2  True  0.840  0.975   0.840   0.975     nan     nan    Manuel
# 25         2  True  0.229  0.678   0.249   0.667     nan     nan     LucaS
# 27         2  True  0.447  0.519     nan     nan   0.447   0.518  Isabella
# 33         2  True  0.389  0.270   0.986   0.000   0.141   0.382     Marta
# 34         2  True  0.040  0.502     nan     nan   0.042   0.534     Mirko
# 35         2  True  0.642  0.949   0.641   0.948     nan     nan    Flavio
# 42         2  True  0.329  0.188   0.166   0.165   0.342   0.190     Carlo

# %%
agg_viz.scatter()

# %%
agg_viz.baby('Carlo')

# %%
agg_viz.stimuli()

# %%
for baby, vas in agg.per_baby.items():
    for va in vas:
        if va.ill_formed:
            continue
            
        if 'rep' in va.get_adult_df().tag.unique():
            print(va.filename)
# Out:
# resources/Claudio/Claudio_(6-12)_7.txt
# resources/Manuel/Manuel_(0-6)_7.txt

# %%
show_baby('Carlo')

# %%
agg.autists, agg.tds
# Out:
# ({'Arianna',
#   'Carlo',
#   'Claudio',
#   'Flavio',
#   'Isabella',
#   'Lorenzo',
#   'LucaS',
#   'Manuel',
#   'Marco',
#   'Marta',
#   'Matteo',
#   'Melissa',
#   'Mirko'},
#  {'Andrea I',
#   'AndreaT II',
#   'Chiara',
#   'Duccio',
#   'Ester',
#   'Francesca',
#   'Francesco',
#   'Giullia',
#   'Jacopo',
#   'LucaT',
#   'Martina',
#   'Michelangelo'})

# %%
show_baby('Francesca', 0)
# Out:
# Francesca est TD

# %%
tags = set()
for ll in agg.per_baby.values():
    for x in ll:
        try:
            tags.update(x.df.tag.unique())
        except Exception as e:
            print(x.filename)
tags
# Out:
# resources/LucaS/LucaS_(0-6)_13.txt
# resources/AndreaT II/AndreaT_(0-6)_1.txt
# resources/Duccio/Duccio_(6-12)_24.txt
# {'avec',
#  'chant',
#  'init',
#  'inv',
#  'mama',
#  'obj',
#  'parle',
#  'rep',
#  'sans',
#  'sons',
#  'touch'}
